# %%
class a_sample_class:
    #default constrstuctor
    def __init__(self_:(slef, one, two)
        self.var = 0
    def print_vars(self):
        print(self.var)
obj = a _sample_class(2,8)
obj.print_vars()
# Out:
#   Cell In[6], line 4
#     self.var = 0
#     ^
# SyntaxError: invalid syntax

# %%
class a_sample_class:
    class_attr = 5
    first = 6

    def __init__(self, one, two):
        self.first = one
        self.second =two
obj = a_sample_class(17,42)
print(obj.first)
print(obj.class_attr)
print(a_sample_class.first)
print(a_sample_class.class_attr)
# Out:
# 17
# 5
# 6
# 5

# %%
help(obj)
# Out:
# Help on a_sample_class in module __main__ object:
#
# class a_sample_class(builtins.object)
#  |  a_sample_class(one, two)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, one, two)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  class_attr = 5
#  |
#  |  first = 6

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a_sample_class',
#  'exit',
#  'get_ipython',
#  'obj',
#  'open',
#  'quit']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class a_sample_class:\n    #default constrstuctor\n    def __init__(self_:\n         self.var = 0\n    def print_vars(self):\n    print(self.var)\nobj = a _sample_class()',
#   'class a_sample_class:\n    #default constrstuctor\n    def __init__(self_:\n         self.var = 0\n    def print_vars(self):\n    print(self.var)\nobj = a _sample_class()\nobj.print_vars()',
#   'class a_sample_class:\n    #default constrstuctor\n    def __init__(self_:\n         self.var = 0\n    def print_vars(self):\n        print(self.var)\nobj = a _sample_class()\nobj.print_vars()',
# ...

# %%
class Candy:
    #variables that start with a single underscore is reserved for internal purposes
    def __init__(self, _brand,
                 _is_caramel=False,
                 _is_chocalate=False,
                 _is_vegan=False, 
                 _has_nuts=False,
                 _type='chocolate'
                 _calories=200):
         self.brand = _brand
         self.is_caramel = _is_caramel
         self.is_chocoalate = _is_chocolate
         self.is_vegan = _is_vegan
         self.has_nuts = _has_nuts
         self.calories = _calories
        #class method- used to modify the state of 
       
    def snickers(cls):
            return cls('Mars',_is_caramel=True, _has_nuts=True, type='Snickers')
        #instance method can access and modify  both the class and instance state
        #print is accessing state
        def display(self):
            print(f"My favorite candy is '{self.brand}{self.type}'
# Out:
#   File <tokenize>:22
#     def display(self):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
Milky_Way =Candy(_brand='hersheys',_is_chocolate=True,_has_nuts=True,_type='Recces')
Milky_Way.display()
def calories (size,n):
    if size == 'large'
        calories = 500
    elif size == 'regular'
        calories = 350
    elif size == 'funsized'
        calories = 200
    candy.calories ('funsized',50)
# Out:
#   Cell In[22], line 4
#     if size == 'large'
#                       ^
# SyntaxError: invalid syntax

# %%
def the_decorator(func):
    print("decorator is running")
    func()
    print("still running")
def oh_hi():
    print("Hello there!")
hello =the_decorator(oh_hi)
# Out:
# decorator is running
# Hello there!
# still running

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Classdata_df = pd.read_csv("CSCI_Fall_2024_survey.csv")
Classdata_df["Age"]=np.where(Classdata_df["How old are you?"]==17,
                             np.where(Classdata_df["How old are you?"]==18,
                                      np.where(Classdata_df["How old are you?"]==19,
                                               np.where(Classdata_df["How old are you?"]==20,
                                                       np.where(Classdata_df["How old are you"]==21,"Unknown",))))

agg_Age = Classdata_df["Age"].value_counts()
colors = ['pink', 'sky blue', 'yellow', 'purple', 'red']  # Adjust colors as needed
agg_Age.plot(kind="pie", colors=colors)
plt.title('Age Distribution')
plt.ylabel('') 
plt.show()
#This is a pie graph that shows the distribution of age in our class.
# Out:
#   Cell In[90], line 11
#     colors = ['pink', 'sky blue', 'yellow', 'purple', 'red']  # Adjust colors as needed
#     ^
# SyntaxError: invalid syntax

# %%
#Distribution of Majors,HIST
#This is supposed to be a histogram showing how many data science majors are in the class.
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from PIL import Image
Classdata_df = pd.read_csv("CSCI_Fall_2024_survey.csv")
class_labels = LabelEncoder()
# Standardize majors
Classdata_df["Major"] = np.where(Classdata_df["What is your major?"] == "Economics", "ECON",
                       np.where(Classdata_df["What is your major?"] == "computer science", "Computer Science",
                       np.where(Classdata_df["What is your major?"] == "Data Science", "Data Science",
                       np.where(Classdata_df["What is your major?"] == "Biology", "Biology",
                       np.where(Classdata_df["What is your major?"] == "CS/Business", "CS/Business",
                       np.where(Classdata_df["What is your major?"] == "cs/finance", "CS/Finance", "N/A"))))))

Major_count= Classdata_df["Major"].value_counts()

Major_count.plot(kind="bar")
plt.xlabel('Major')
plt.ylabel('Count')
plt.title('Histogram of Major')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid()

# %%
# This should return as a pie chart for how many people like food in country categories. 

# Standardize food preferences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
classdata_df = pd.read_csv("CSCI_Fall_2024_survey.csv")

# Standardize food preferences
classdata_df["Food_df"] = np.where(classdata_df["What is your favorite type of food?"] == "Japanese", "Japan",
                    np.where(classdata_df["What is your favorite type of food?"] == "korean", "Korea",
                    np.where(classdata_df["What is your favorite type of food?"] == "Italian", "Italy",
                    np.where(classdata_df["What is your favorite type of food?"] == "American", "USA",
                    np.where(classdata_df["What is your favorite type of food?"] == "Mexican", "Mexico",
                    np.where(classdata_df["What is your favorite type of food?"] == "Indian", "India",
                    np.where(classdata_df["What is your favorite type of food?"] == "Chinese", "China", "all of the above")))))))
agg_food = classdata_df["Food_df"].value_counts()

colors = ['pink', 'blue', 'green', 'orange', 'yellow', 'purple', 'red']  # Adjust colors as needed
agg_food.plot(kind="pie", y = "Food", colors=colors)

# Customize plot
plt.title('Food Preference')
plt.ylabel('')  # Remove y-label for better appearance
plt.show()

# %%
#How many pets and of which kind do you have?, HISY 
#This is supposed to be a histogram showing how many pets people have.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
classdata_df = pd.read_csv("CSCI_Fall_2024_survey.csv")
# Standardize pets
Classdata_df["Pets"] = np.where(Classdata_df["How many pets and of which kind do you have?"] == "0", "zero pets",
                     np.where(Classdata_df["How many pets and of which kind do you have?"] == "1", "one pet",
                     np.where(Classdata_df["How many pets and of which kind do you have?"] == "I have two dogs and they are both at home", "two pets",
                     np.where(Classdata_df["How many pets and of which kind do you have?"] == "2 cats, one dog", "three pets",
                     np.where(Classdata_df["How many pets and of which kind do you have?"] == "6 Dogs (Over two households)", "six pets",
                     np.where(Classdata_df["How many pets and of which kind do you have?"] == "had 8 dogs, not anymore", "eight pets", "no pets"))))))
plt.plot(Classdata_df["Pets"], Classdata_df["Age"],'.')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
classdata_df = pd.read_csv("CSCI_Fall_2024_survey.csv")

#standardize Birthplace
Classdata_df["Birth"] = np.where(Classdata_df["What state/country were you born in?"] == "I was born in Chandigarh, India!", "India",
                       np.where(Classdata_df["What state/country were you born in?"] == "Kazakhstah", "Kazakhstan",
                       np.where(Classdata_df["What state/country were you born in?"] == "Cameroon", "Cameroon",
                       np.where(Classdata_df["What state/country were you born in?"] == "People's Republic of China", "China",
                       np.where(Classdata_df["What state/country were you born in?"] == "Georgia", "Georgia",
                       np.where(Classdata_df["What state/country were you born in?"] == "India", "India",
                       np.where(Classdata_df["What state/country were you born in?"] == "Frankfurt, Germany", "Germany",
                       np.where(Classdata_df["What state/country were you born in?"] == "Mexico", "Mexico",
                       np.where(Classdata_df["What state/country were you born in?"] == "Wisconsin",
                       np.where(Classdata_df["What state/country were you born in?"] == "New Jersey",
                       np.where(Classdata_df["What state/country were you born in?"] == "Oklahoma",
                       np.where(Classdata_df["What state/country were you born in?"] == "Kansas, Overland Park"
                       np.where(Classdata_df["What state/country were you born in?"] == "Missouri","Missouri","st. louis, mo","St. Louis MO","Missouri, USA","Saint Louis, Missouri")))))))))
Birth_count= Classdata_df["Birth"].value_counts()

Birth_count.plot(kind="bar")
plt.xlabel('Birth')
plt.ylabel('Count')
plt.title('Histogram of Birth')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid()

#This is a histogram about the birthplaces of people outside the US and states inside the US
# Out:
#   Cell In[96], line 19
#     np.where(Classdata_df["What state/country were you born in?"] == "Missouri","Missouri","st. louis, mo","St. Louis MO","Missouri, USA","Saint Louis, Missouri")))))))))
#     ^
# SyntaxError: invalid syntax

# %%
Classdata_df.head(20)
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...
